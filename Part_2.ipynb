# %% [markdown]
# # Part 2

# %%
import pickle

with open('interactions.pickle', 'rb') as handle:
    my_dict = pickle.load(handle)

# %%
my_dict
# Out:
# {9: [(8, 12, 7, 2008, 10), (72, 13, 7, 2008, 10)],
#  1: [(1, 12, 7, 2008, 10), (91, 18, 8, 2008, 5)],
#  13: [(1, 12, 7, 2008, 10),
#   (23, 12, 7, 2008, 10),
#   (11, 12, 7, 2008, 10),
#   (23, 12, 7, 2008, 10)],
#  17: [(1, 12, 7, 2008, 10),
#   (1, 12, 7, 2008, 10),
#   (32, 12, 7, 2008, 10),
#   (17, 12, 7, 2008, 10),
#   (72, 12, 7, 2008, 10),
#   (48, 13, 7, 2008, 10),
#   (83, 13, 7, 2008, 10),
#   (2064, 22, 8, 2008, 2)],
#  48: [(2, 12, 7, 2008, 10), (91, 13, 7, 2008, 10)],
#  19: [(9, 12, 7, 2008, 10)],
#  23: [(23, 12, 7, 2008, 10)],
#  35: [(33, 12, 7, 2008, 10), (58, 12, 7, 2008, 10), (71, 13, 7, 2008, 10)],
#  39: [(33, 12, 7, 2008, 10),
#   (40, 12, 7, 2008, 10),
#   (8, 12, 7, 2008, 10),
#   (91, 13, 7, 2008, 10)],
#  43: [(22, 12, 7, 2008, 10)],
#  37: [(40, 12, 7, 2008, 10)],
#  45: [(45, 12, 7, 2008, 10)],
#  49: [(13, 12, 7, 2008, 10), (109, 13, 7, 2008, 10), (91, 13, 7, 2008, 10)],
#  50: [(37, 12, 7, 2008, 10),
#   (2089740, 13, 7, 2008, 10),
# ...
